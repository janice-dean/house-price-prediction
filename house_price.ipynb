# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test=pd.read_csv("/workspaces/house-price-prediction/test (1).csv")

# %%
test.sample()
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 401  1862          90       RL          NaN    11855   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 401         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 401       0     10    2009        WD         Normal
#
# [1 rows x 80 columns]

# %%
test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   str
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   str
#  6   Alley          107 non-null    str
#  7   LotShape       1459 non-null   str
#  8   LandContour    1459 non-null   str
#  9   Utilities      1457 non-null   str
#  10  LotConfig      1459 non-null   str
#  11  LandSlope      1459 non-null   str
#  12  Neighborhood   1459 non-null   str
#  13  Condition1     1459 non-null   str
#  14  Condition2     1459 non-null   str
#  15  BldgType       1459 non-null   str
#  16  HouseStyle     1459 non-null   str
#  17  OverallQual    1459 non-null   int64
# ...

# %%
test.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
null_percentage=(test.isnull().sum()/len(test))*100
print(null_percentage)
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.274160
# LotFrontage      15.558602
# LotArea           0.000000
#                    ...
# MiscVal           0.000000
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.068540
# SaleCondition     0.000000
# Length: 80, dtype: float64

# %%
null_percentage=(test.isnull().sum()/len(test))*100 # find % of null values
print(null_percentage[null_percentage > 80])  # find % above 80%
# Out:
# Alley          92.666210
# PoolQC         99.794380
# Fence          80.123372
# MiscFeature    96.504455
# dtype: float64

# %%
test.drop(columns=["Alley", "PoolQC", "Fence", "MiscFeature"])
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
# filling null values
print(test["LotFrontage"].mean()) 
test["LotFrontage"]=test["LotFrontage"].fillna(68) # not permanent so use inplace=True or save it
# Out:
# 68.58035714285714

# %%
test.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         1
# SaleCondition    0
# Length: 80, dtype: int64

# %%
print(test['MSZoning'].mode())
test['MSZoning']=test['MSZoning '].fillna("S")
# Out:
# 0    RL
# Name: MSZoning, dtype: str
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MSZoning '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#encoding converting catagorical into numerical
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
test[""]
